# %%
# entendendo conceitos

# txt ='oi'
# num =1
# qlq_num =0.5

# lista = ['Meu nome no texto', 24, [1,4,20]]

# # for item in lista[2]:
# #     print(f'Item --> {item}')

# nome_var =True
# # if nome_var:
# #     print('True')

# # else:
# #     print('False')

# valor =0

# while valor <=10000:
#     valor +=1
#     if valor %2 ==0:
#         continue
#     print(f'{valor}')



# *****************************************************
# parte dois

# Criar cadastro simples
# *****************************************************

cadastrados =[]
nome_cadastrados =[]
email_cadastrados =[]
cpf_cadastrados =[]

while True:
    print('━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━')
    print('Digite 0 para sair')
    print('Digite 1 para cadastrar usuario')
    print('━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━')
    print('')

    opc =int(input('o que você deseja? '))
    print('')

    if opc ==0:
        if len(cadastrados) ==0:
            break

        else:
            print(cadastrados)
            break

    elif opc ==1:
        nome =input('Digite o nome para cadastro: ')
        print('')

        email =input('Digite o email para cadastro: ')
        print('')

        cpf =float(input('Digite o cpf para cadastro: '))
        print('')

        nome_cadastrados.append(nome)
        email_cadastrados.append(email)
        cpf_cadastrados.append(cpf)
        cadastrados.extend([nome_cadastrados, email_cadastrados, cpf_cadastrados])
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Digite 0 para sair
# Digite 1 para cadastrar usuario
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
#
#
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Digite 0 para sair
# Digite 1 para cadastrar usuario
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#
# [['adada'], ['adad@'], [331312.0]]
