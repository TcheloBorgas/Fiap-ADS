# %%
import pandas as pd

# %%
data =pd.read_csv('animation_series.csv')
# display(data)

# %%
# Filtrar os filmes com classificação igual ou superior a 5
rating =input('Digite a nota: ')

filtered_data = data[data['Rating'] >= rating]

# Mostrar as primeiras linhas dos filmes filtrados
filtered_data.head()
# Out:
#                                  Title    IMDb ID Release Year
# 0  Spider-Man: Across the Spider-Verse  tt9362722         2023  \
# 1          The Super Mario Bros. Movie  tt6718170         2023
# 2    Spider-Man: Into the Spider-Verse  tt4633694         2018
# 3       Demon Slayer: Kimetsu no Yaiba  tt9335498       2019–
# 4                   The Little Mermaid  tt0097757         1989
#
#                           Genre
# 0  Animation, Action, Adventure  \
# 1  Animation, Adventure, Comedy
# 2  Animation, Action, Adventure
# 3  Animation, Action, Adventure
# 4  Animation, Adventure, Family
#
#                                                 Cast
# 0  Directors:, Joaquim Dos Santos, , Kemp Powers,...  \
# 1  Directors:, Aaron Horvath, , Michael Jelenic, ...
# 2  Directors:, Bob Persichetti, , Peter Ramsey, ,...
# 3  Stars:, Natsuki Hanae, , Zach Aguilar, , Akari...
# 4  Directors:, Ron Clements, , John Musker, | ,  ...
#
# ...
